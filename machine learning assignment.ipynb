# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('F:/quantity_price.xlsx')

# %%
df=pd.DataFrame(df,columns=['quantity','price'])

# %%
df
# Out:
#     quantity  price
# 0         10    100
# 1         20    200
# 2         10    100
# 3         30    300
# 4         40    400
# 5         50    500
# 6         80   6000
# 7         90    700
# 8        100    800
# 9        120    900
# 10       130   1000
# 11       140   1100
# 12       150   1200
# 13       160   1300
# 14       170   1400
# 15       180   1500
# 16       190   1600
# 17       200   1700
# 18       210   1800
# 19       220   1900
# 20       230   2000
# 21       240   2100
# 22       250   2200
# 23       260   2300
# 24       270   2400
# 25       280   2500
# 26       290   2600
# 27       300   2700
# 28       310   2800
# 29       320   2900

# %%
df.plot.scatter(x='quantity',y='price')
# Out:
# <AxesSubplot:xlabel='quantity', ylabel='price'>

# %%
x=df[['quantity']]

# %%
x
# Out:
#     quantity
# 0         10
# 1         20
# 2         10
# 3         30
# 4         40
# 5         50
# 6         80
# 7         90
# 8        100
# 9        120
# 10       130
# 11       140
# 12       150
# 13       160
# 14       170
# 15       180
# 16       190
# 17       200
# 18       210
# 19       220
# 20       230
# 21       240
# 22       250
# 23       260
# 24       270
# 25       280
# 26       290
# 27       300
# 28       310
# 29       320

# %%
y=df[['price']]

# %%
y
# Out:
#     price
# 0     100
# 1     200
# 2     100
# 3     300
# 4     400
# 5     500
# 6    6000
# 7     700
# 8     800
# 9     900
# 10   1000
# 11   1100
# 12   1200
# 13   1300
# 14   1400
# 15   1500
# 16   1600
# 17   1700
# 18   1800
# 19   1900
# 20   2000
# 21   2100
# 22   2200
# 23   2300
# 24   2400
# 25   2500
# 26   2600
# 27   2700
# 28   2800
# 29   2900

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
xtrain
# Out:
#     quantity
# 27       300
# 11       140
# 17       200
# 22       250
# 5         50
# 16       190
# 8        100
# 14       170
# 23       260
# 20       230
# 1         20
# 29       320
# 6         80
# 4         40
# 18       210
# 19       220
# 9        120
# 7         90
# 25       280
# 3         30
# 0         10
# 21       240
# 15       180
# 12       150

# %%
ytrain
# Out:
#     price
# 27   2700
# 11   1100
# 17   1700
# 22   2200
# 5     500
# 16   1600
# 8     800
# 14   1400
# 23   2300
# 20   2000
# 1     200
# 29   2900
# 6    6000
# 4     400
# 18   1800
# 19   1900
# 9     900
# 7     700
# 25   2500
# 3     300
# 0     100
# 21   2100
# 15   1500
# 12   1200

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(xtest)

# %%
xtest
# Out:
#     quantity
# 2         10
# 28       310
# 13       160
# 10       130
# 26       290
# 24       270

# %%
predictions
# Out:
# array([[ 599.16888298],
#        [2611.8018617 ],
#        [1605.48537234],
#        [1404.22207447],
#        [2477.62632979],
#        [2343.45079787]])

# %%
ytest
# Out:
#     price
# 2     100
# 28   2800
# 13   1300
# 10   1000
# 26   2600
# 24   2400

# %%
predictions=pd.DataFrame(predictions,columns=['predictions'])

# %%
predictions
# Out:
#    predictions
# 0   599.168883
# 1  2611.801862
# 2  1605.485372
# 3  1404.222074
# 4  2477.626330
# 5  2343.450798

# %%
sns.regplot(x='quantity',y='price',data=df,fit_reg=True)
# Out:
# <AxesSubplot:xlabel='quantity', ylabel='price'>
